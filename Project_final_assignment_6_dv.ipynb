# %%
#Final Project – Data Analytics
#The purpose of this project is to learn to create analyses and visualizations that are useful in real life.
#You are required to choose one dataset from four provided datasets. The datasets will be available for download on Apr 15. Complete all requirements outlined below for the dataset you have chosen.
#Requirements
#Your analysis should include:
#1. At least two statistical summary (mean, sum, count, median etc).
#2. At least two analyses of patterns, relationship etc. found in the data.
#3. At least two visualizations - at least one for statistical summary, at least one for analysis.
#4. A written summary of no less than 200 words describing the analysis and the results.


import pandas as pd
from matplotlib import pyplot as plt

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_palette('RdYlGn_r')

#importing the csv file
df=pd.read_csv('world_happiness_report_2020.csv')

# %%
#1. At least two statistical summary (mean, sum, count, median etc).
df.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe        7.8087              10.639267
# 1      Denmark     Western Europe        7.6456              10.774001
# 2  Switzerland     Western Europe        7.5599              10.979933
# 3      Iceland     Western Europe        7.5045              10.772559
# 4       Norway     Western Europe        7.4880              11.087804
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0        0.954330                71.900825                      0.949172
# 1        0.955991                72.402504                      0.951444
# 2        0.942847                74.102448                      0.921337
# 3        0.974670                73.000000                      0.948892
# 4        0.952487                73.200783                      0.955750
#
#    Generosity  Perceptions of corruption
# 0   -0.059482                   0.195445
# ...

# %%
df.describe()
# Out:
#        Ladder score  Logged GDP per capita  Social support  \
# count     153.00000             153.000000      153.000000
# mean        5.47324               9.295706        0.808721
# std         1.11227               1.201588        0.121453
# min         2.56690               6.492642        0.319460
# 25%         4.72410               8.350645        0.737217
# 50%         5.51500               9.456313        0.829204
# 75%         6.22850              10.265124        0.906747
# max         7.80870              11.450681        0.974670
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               153.000000                    153.000000  153.000000
# mean                 64.445529                      0.783360   -0.014568
# std                   7.057848                      0.117786    0.151809
# min                  45.200001                      0.396573   -0.300907
# ...

# %%
df.groupby(['Social support', 'Ladder score', 'Logged GDP per capita' ,	'Social support', 'Healthy life expectancy' , 'Freedom to make life choices', 'Generosity' ,'Perceptions of corruption']).sum()
# Out:
#                                                                                                                                                                         Country name  \
# Social support Ladder score Logged GDP per capita Social support Healthy life expectancy Freedom to make life choices Generosity Perceptions of corruption
# 0.319460       3.4759       6.625160              0.319460       45.200001               0.640881                      0.082410  0.891807                   Central African Republic
# 0.468671       5.2160       7.674320              0.468671       54.312466               0.735183                     -0.003537  0.740533                                      Benin
# 0.470367       2.5669       7.462861              0.470367       52.590000               0.396573                     -0.096429  0.933687                                Afghanistan
# ...

# %%
df_report=df
df_report.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe        7.8087              10.639267
# 1      Denmark     Western Europe        7.6456              10.774001
# 2  Switzerland     Western Europe        7.5599              10.979933
# 3      Iceland     Western Europe        7.5045              10.772559
# 4       Norway     Western Europe        7.4880              11.087804
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0        0.954330                71.900825                      0.949172
# 1        0.955991                72.402504                      0.951444
# 2        0.942847                74.102448                      0.921337
# 3        0.974670                73.000000                      0.948892
# 4        0.952487                73.200783                      0.955750
#
#    Generosity  Perceptions of corruption
# 0   -0.059482                   0.195445
# ...

# %%
#Result: In the first table we see the first 4 country and I created the general table that show you the data.
#The second table we use describe to give us count, mean, sum and median of the report that we are showing above.
#I also added extra tables of all the statistical data has been group to show the sum. What we can see that the max number is 7
#the rest of the data varies between 1-9. The highest for the Mean is Healthy life expectancy at 64.445529 
#and the lowest Generosity at negative -0.014568

# %%
#2. At least two analyses of patterns, relationship etc. found in the data.

# let's plot pair plot to visualise the attributes all at once
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  153 non-null    object
#  1   Regional indicator            153 non-null    object
#  2   Ladder score                  153 non-null    float64
#  3   Logged GDP per capita         153 non-null    float64
#  4   Social support                153 non-null    float64
#  5   Healthy life expectancy       153 non-null    float64
#  6   Freedom to make life choices  153 non-null    float64
#  7   Generosity                    153 non-null    float64
#  8   Perceptions of corruption     153 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 10.9+ KB

# %%
cols = df[['Ladder score', 'Logged GDP per capita','Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]
plt.figure(figsize=(20, 8))
sns.heatmap(cols.corr(), annot = True, cmap='RdYlGn_r', mask=np.triu(np.ones_like(cols.corr())));
plt.title('Correlations between factors', fontsize=15, fontweight='bold', pad=30);

# %%
#I wanted to include a heat map because it was hard to see differentiate the correlation between 
#each country
#Result:
#I am only analysis 
#'Social support', 'Healthy life expectancy','Freedom to make life choices', 
#'Generosity'

#-On the top is Social support and Healthy life expectancy, Ladder score, Logged GDP per Capita 
#-unfortunately Freedom to make life choices and Generosity was on the bottom 
#The correlated with the first question where in the mean Generosity was at the lowest. 
#Suprisely in the line plot that we created earlier Generosity gave us and steady result but 
#among the columns it still the lowest.

# %%
df_older = pd.read_csv('world_happiness_report_2020.csv')
norway_1 = df_older[df_older['Country name'] == 'Norway'].reset_index(drop=True) 
norway_1 = norway_1.fillna(0)
df_report['year'] = 2020
norway_2 = df_report[df_report['Country name'] == 'Norway']
norway = pd.concat([norway_1, norway_2])
norway.reset_index(drop=True, inplace=True)
norway.rename(columns = {'year':'Year'}, inplace=True)
norway
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0       Norway     Western Europe         7.488              11.087804
# 1       Norway     Western Europe         7.488              11.087804
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0        0.952487                73.200783                       0.95575
# 1        0.952487                73.200783                       0.95575
#
#    Generosity  Perceptions of corruption    Year
# 0    0.134533                   0.263218     NaN
# 1    0.134533                   0.263218  2020.0

# %%
#2. At least two analyses of patterns, relationship etc. found in the data.

# %%
#Note that there is no concept of "change" in this dataset because each row represents the final score of each country in the year 2020.
#The chart above is simply putting the data points into a chart and is not an analysis of relationship.
#I would suggest to explore the correlation between a factor (e.g. social support) 
#and the ladder score (which prepresents happiness in this dataset).
#For example:
#do countries that have a high ladder score generally have a high social support score?
#Does ladder score generally go up if social support score goes up? 
#If so, is the correlation consistent across countries? 
#If not, is it more significant in certain regions e.g. Europe but not the others?
#You can consider using a scatter plot to explore the correlation.
#https://www.w3schools.com/python/matplotlib_scatter.asp

#Also, please adjust the figure size so that all the labels are legible. 

df.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe        7.8087              10.639267
# 1      Denmark     Western Europe        7.6456              10.774001
# 2  Switzerland     Western Europe        7.5599              10.979933
# 3      Iceland     Western Europe        7.5045              10.772559
# 4       Norway     Western Europe        7.4880              11.087804
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0        0.954330                71.900825                      0.949172
# 1        0.955991                72.402504                      0.951444
# 2        0.942847                74.102448                      0.921337
# 3        0.974670                73.000000                      0.948892
# 4        0.952487                73.200783                      0.955750
#
#    Generosity  Perceptions of corruption  year
# 0   -0.059482                   0.195445  2020
# ...

# %%
df.plot.scatter(x='Freedom to make life choices', y= 'Generosity')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='Generosity'>

# %%
import seaborn as sns

sns.set_style('white')
sns.set_style ('ticks')

sns.regplot(x='Ladder score', y='Social support', color='tab:pink', data=df)
# Out:
# <AxesSubplot:xlabel='Ladder score', ylabel='Social support'>

# %%
sns.lmplot(x='Ladder score', y='Social support', hue='Country name', data=df)

##do countries that have a high ladder score generally have a high social support score?
#Countries that have high ladder and social support Denmark, Switzerland, Finland. 
#Does ladder score generally go up if social support score goes up? Yes, 
#the correlation between them ae pretty even. 
#If so, is the correlation consistent across countries?  No, Afghanistan, South sudan
#and zimbabwe are the lowest on social support and ladder score
#Europe is the most wealthy.

# %%
sns.pairplot(df)

# %%
#Result;
#1950-2100 the report has not change however it's making a prediction that it might change around year 2100.
#Perception, Generosity of corruption is the same but the prediction that won't vary between the year no change
#Freedom to make a choice looks like it going up the same as healthy life expendency from the graph prediction
#to even be higher in the future. Social support, Logged GDP per capita and Ladder score  the correlation between
#if one goes up the other will increase making a straigh line.

# %%
#3.At least two visualizations - at least one for statistical summary, at least one for analysis.
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('world_happiness_report_2020.csv')

# Filtering df for ratings with 5 stars.
df = df[df['Healthy life expectancy'] >70]

# Grouping by brands
df = df.groupby('Country name').count()

# Filtering brands rated 5 star for atleast 5 times.  
df1 = df[df['Healthy life expectancy'] >=2]

df.reset_index(level=0, inplace=True)
plt.pie(df['Healthy life expectancy'], labels=df['Country name'])
plt.show()

# %%
#Results; It looks like that most country life expectancy are greater than 70, however I am showing
#two pie chart changing the number to 75 it seem like Japan, Singapore and Hong Kong China have the life 
#expectancy greater than 75, while the other country it stops at 70.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12, 4))

# creating the bar plot
plt.bar(df['Country name'],df['Generosity'])

  
plt.xticks(rotation=90)
plt.xlabel("Country name")
plt.ylabel("Ladder score")
plt.title("Generosity")

plt.show()

# %%
#Results: I createda bar graph to see all the country that show Ladder score comparing it to Generosity
#All the country have the same number between those two them.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('world_happiness_report_2020.csv')

# Filtering df by healthy life less 70
df = df[df['Healthy life expectancy'] >75]

# Grouping by countries
df = df.groupby('Country name').count()

# Filtering Healthy less than than 2
df1 = df[df['Healthy life expectancy'] >=2]

df.reset_index(level=0, inplace=True)
plt.pie(df['Healthy life expectancy'], labels=df['Country name'])
plt.show()

# %%
#Results; It looks like that most country life expectancy are greater than 70, however I am showing
#two pie chart changing the number to 75 it seem like Japan, Singapore and Hong Kong China have the life 
#expectancy greater than 75, while the other country it stops at 70.
